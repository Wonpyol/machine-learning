# %%
from IPython.display import Image
import os

# !python detect_video.py --weights best.pt --img 416 --conf 0.5 --source 'rtsp://admin:admin@210.221.233.212/z3-1.sdp'
# Out:
# Namespace(agnostic_nms=False, augment=False, classes=None, conf_thres=0.5, device='', exist_ok=False, img_size=416, iou_thres=0.45, name='exp', project='runs/detect', save_conf=False, save_txt=False, source='rtsp://admin:admin@210.221.233.212/z3-1.sdp', update=False, view_img=False, weights=['best.pt'])
# YOLOv5 🚀 v4.0-138-ged2c742 torch 1.8.0 CPU
#
# Fusing layers...
# Model Summary: 392 layers, 46600566 parameters, 0 gradients, 114.1 GFLOPS
# 1/1: rtsp://admin:admin@210.221.233.212/z3-1.sdp...  success (3840x2160 at 29.97 FPS).
#
# 0: 256x416 Done. (0.593s)
# Traceback (most recent call last):
#   File "detect_video.py", line 175, in <module>
#     detect()
#   File "detect_video.py", line 134, in detect
#     fps = vid_cap.get(cv2.CAP_PROP_FPS)
# AttributeError: 'NoneType' object has no attribute 'get'

# %%
# !python detect_video.py --weights best.pt --img 416 --conf 0.5 --source '/Users/wonpyolee/work/mss_video/x41Test.mp4'
# Out:
# Namespace(agnostic_nms=False, augment=False, classes=None, conf_thres=0.5, device='', exist_ok=False, img_size=416, iou_thres=0.45, name='exp', project='runs/detect', save_conf=False, save_txt=False, source='/Users/wonpyolee/work/mss_video/x41Test.mp4', update=False, view_img=False, weights=['best.pt'])
# YOLOv5 🚀 v4.0-138-ged2c742 torch 1.8.0 CPU
#
# Fusing layers...
# Model Summary: 392 layers, 46600566 parameters, 0 gradients, 114.1 GFLOPS
# video 1/1 (1/3659) /Users/wonpyolee/work/mss_video/x41Test.mp4: 256x416 Done. (0.499s)
# video 1/1 (2/3659) /Users/wonpyolee/work/mss_video/x41Test.mp4: 256x416 Done. (0.491s)
# video 1/1 (3/3659) /Users/wonpyolee/work/mss_video/x41Test.mp4: 256x416 Done. (0.486s)
# video 1/1 (4/3659) /Users/wonpyolee/work/mss_video/x41Test.mp4: 256x416 Done. (0.502s)
# video 1/1 (5/3659) /Users/wonpyolee/work/mss_video/x41Test.mp4: 256x416 Done. (0.497s)
# video 1/1 (6/3659) /Users/wonpyolee/work/mss_video/x41Test.mp4: 256x416 Done. (0.499s)
# ...
